# %% [markdown]
# 4.9 Part 1

# %% [markdown]
# 1. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 2. Import Dataframe

# %%
# Create String of Path to Main Project Folder
path = r'/Users/seema/Documents/CareerFoundry/A4/Instacart Basket Analysis'

# %%
# Import Dataframes
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# 3. Data Wrangling

# %%
df_customers.head(20)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
# Rename Columns
df_customers.rename(columns = {'First Name' : 'first_name'}, inplace = True)
df_customers.rename(columns = {'Surnam' : 'last_name'}, inplace = True)
df_customers.rename(columns = {'Gender' : 'gender'}, inplace = True)
df_customers.rename(columns = {'STATE' : 'state'}, inplace = True)
df_customers.rename(columns = {'Age' : 'age'}, inplace = True)
df_customers.rename(columns = {'n_dependents' : '#_dependents'}, inplace = True)

# %%
df_customers.head(5)
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Descriptive Statistics
df_customers.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# Change user_id to String
df_customers['user_id'] = df_customers['user_id'].astype('str')

# %%
df_customers['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# 4. Data Consistency

# %%
# Find Missing Values
df_customers.isnull().sum()
# Out:
# user_id             0
# first_name      11259
# last_name           0
# gender              0
# state               0
# age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# Show Null Values
df_nan = df_customers[df_customers['first_name'].isnull() == True]
df_nan
# Out:
#        user_id first_name last_name  gender         state  age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %% [markdown]
# I plan to keep the rows with missing first name data given that this is the only missing value.

# %%
# Find Full Duplicates
df_dups = df_customers[df_customers.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %% [markdown]
# There does not appear to be any duplicate data that needs to be removed.

# %%
# Export Dataframe
df_customers.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers_wrangled.pkl'))

# %% [markdown]
# 5. Combine Data

# %%
# Import Dataframes
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_flagged.pkl'))
df_customers = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'customers_wrangled.pkl'))

# %% [markdown]
# 5.1 Analyze Dataframes

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  orders_#  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1         1                   2                  8
# 1   2398795        1         2                   3                  7
# 2    473747        1         3                   3                 12
# 3   2254736        1         4                   4                  7
# 4    431534        1         5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...     busiest day     busiest_day  busiest_days  \
# ...

# %%
df_customers.head()
# Out:
#   user_id first_name last_name  gender       state  age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_ords_prods.shape
# Out:
# (32404859, 25)

# %%
df_customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# The customers dataframe is significantly smaller than the orders products dataframe.

# %%
df_ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   order_id                 int64
#  1   user_id                  int64
#  2   orders_#                 int64
#  3   orders_day_of_week       int64
#  4   order_hour_of_day        int64
#  5   days_since_prior_order   float64
#  6   product_id               int64
#  7   add_to_cart_order        int64
#  8   reordered                int64
#  9   product_name             object
#  10  aisle_id                 int64
#  11  department_id            int64
#  12  prices                   float64
#  13  _merge                   category
#  14  price_range_loc          object
#  15  busiest day              object
#  16  busiest_day              object
#  17  busiest_days             object
#  18  busiest_period_of_day    object
#  19  max_order                int64
# ...

# %%
# Update Integers to Strings
df_ords_prods['user_id'] = df_ords_prods['user_id'].astype('str')
df_ords_prods['order_id'] = df_ords_prods['order_id'].astype('str')
df_ords_prods['product_id'] = df_ords_prods['product_id'].astype('str')
df_ords_prods['aisle_id'] = df_ords_prods['aisle_id'].astype('str')
df_ords_prods['department_id'] = df_ords_prods['department_id'].astype('str')

# %% [markdown]
# 5.2 Merge Dataframes & Export

# %%
# Create Merged Dataframe
df_merged = df_ords_prods.merge(df_customers, on = 'user_id')

# %%
# Check Output & Confirm Merge
df_merged.head()
# Out:
#   order_id user_id  orders_#  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1         1                   2                  8
# 1  2398795       1         2                   3                  7
# 2   473747       1         3                   3                 12
# 3  2254736       1         4                   4                  7
# 4   431534       1         5                   4                 15
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                     NaN        196                  1          0
# 1                    15.0        196                  1          1
# 2                    21.0        196                  1          1
# 3                    29.0        196                  1          1
# 4                    28.0        196                  1          1
#
#   product_name  ...   order_frequency_flag first_name  last_name  gender  \
# 0         Soda  ...  Non-frequent customer      Linda     Nguyen  Female
# ...

# %%
#Checking Values
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export dataframe 
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_custs.pkl'))
